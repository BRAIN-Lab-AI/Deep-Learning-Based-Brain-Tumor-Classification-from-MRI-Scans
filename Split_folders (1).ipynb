# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install git+https://github.com/jfilter/split-folders.git
# Out:
# ...
#   Cloning https://github.com/jfilter/split-folders.git to /tmp/pip-req-build-nim5qd38
#   Running command git clone --filter=blob:none --quiet https://github.com/jfilter/split-folders.git /tmp/pip-req-build-nim5qd38
#   Resolved https://github.com/jfilter/split-folders.git to commit c566dbd56a1097e1ddba2de5dfb93bd67eade54f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for split_folders: filename=split_folders-0.5.1-py3-none-any.whl size=8442 sha256=487246a7dbd5c3306f75223efc6d6da38ea00d06bda8d2b45e29185697fbcb37
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5w_v5s8g/wheels/0f/3d/ee/e13ed93c00d9bb5158ac1717122e0ca4a98428b44be21bad66
# Successfully built split_folders
# ...

# %%
# !pip install split-folders

# %%
import splitfolders

# %%
# Split with a ratio.
# To only split into training and validation set, set a tuple to `ratio`, i.e, `(.8, .2)`.
splitfolders.ratio('/content/drive/MyDrive/BrainTumorProject/DB', output='/content/drive/MyDrive/BrainTumorProject/split_data_80_20',  seed=3, ratio=(.8, .2)) # default values
# Out:
# Copying files: 5153 files [04:14, 20.26 files/s]
